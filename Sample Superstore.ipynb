# %% [markdown]
# # Sample Superstore

# %%
#Import all libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Let's read the dataset and Exploratory data analysis

# %%
df=pd.read_csv('SampleSuperstore1.csv')
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# # Understanding data

# %%
#1.Shape
df.shape
# Out:
# (9994, 13)

# %%
#2.Columns
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
#3.Head and tail:
df.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %%
#4.Indentify the data type:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
#5.Data distribution or statistics summary:
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#6.Identify categorical data in the dataset:
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
#Find the any null values:
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#Duplicated values:
df.duplicated().sum()
# Out:
# 17

# %%
#Remove duplicated values:
df.drop_duplicates(keep='last',inplace=True)

# %%
df.shape
# Out:
# (9977, 13)

# %%
#Renmae the specific columns:
df['Sales']=df['Sales'].astype('int')
df['Profit']=df['Profit'].astype('int')

# %%
df.head(20)
# Out:
#          Ship Mode      Segment        Country             City  \
# 0     Second Class     Consumer  United States        Henderson
# 1     Second Class     Consumer  United States        Henderson
# 2     Second Class    Corporate  United States      Los Angeles
# 3   Standard Class     Consumer  United States  Fort Lauderdale
# 4   Standard Class     Consumer  United States  Fort Lauderdale
# 5   Standard Class     Consumer  United States      Los Angeles
# 6   Standard Class     Consumer  United States      Los Angeles
# 7   Standard Class     Consumer  United States      Los Angeles
# 8   Standard Class     Consumer  United States      Los Angeles
# 9   Standard Class     Consumer  United States      Los Angeles
# 10  Standard Class     Consumer  United States      Los Angeles
# 11  Standard Class     Consumer  United States      Los Angeles
# 12  Standard Class     Consumer  United States          Concord
# 13  Standard Class     Consumer  United States          Seattle
# ...

# %%
#Remove the unwanted column:
df.drop(["Country", "Postal Code"],axis=1,inplace=True)

# %%
df
# Out:
#            Ship Mode    Segment             City       State Region  \
# 0       Second Class   Consumer        Henderson    Kentucky  South
# 1       Second Class   Consumer        Henderson    Kentucky  South
# 2       Second Class  Corporate      Los Angeles  California   West
# 3     Standard Class   Consumer  Fort Lauderdale     Florida  South
# 4     Standard Class   Consumer  Fort Lauderdale     Florida  South
# ...              ...        ...              ...         ...    ...
# 9989    Second Class   Consumer            Miami     Florida  South
# 9990  Standard Class   Consumer       Costa Mesa  California   West
# 9991  Standard Class   Consumer       Costa Mesa  California   West
# 9992  Standard Class   Consumer       Costa Mesa  California   West
# 9993    Second Class   Consumer      Westminster  California   West
#
#              Category Sub-Category  Sales  Quantity  Discount  Profit
# 0           Furniture    Bookcases    261         2      0.00      41
# ...

# %% [markdown]
# *Polished dataset ready for analysis! Efficiently cleaned, this high-quality dataset sets the stage for insightful exploration.*

# %% [markdown]
# # Correlation

# %%
#Numerical columns
num_col=df.corr()
num_col
# Out:
# C:\Users\91934\AppData\Local\Temp\ipykernel_17164\4082442551.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   num_col=df.corr()
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200761 -0.028264  0.479245
# Quantity  0.200761  1.000000  0.008678  0.066232
# Discount -0.028264  0.008678  1.000000 -0.218462
# Profit    0.479245  0.066232 -0.218462  1.000000

# %%
sns.set(rc={'figure.figsize':(8,5)})
sns.heatmap(num_col,annot=True,)
plt.title("Numerical Columns Correlation")
# Out:
# Text(0.5, 1.0, 'Numerical Columns Correlation')

# %%
#Positive Correlation:
sns.lmplot(x='Sales',y='Profit',data=df)
plt.title("Positive Correlation - Sales and Profit")
# Out:
# Text(0.5, 1.0, 'Positive Correlation - Sales and Profit')

# %% [markdown]
# *A positive correlation between sales and profit indicates that as sales increase, profits also rise. This suggests a direct and proportional relationship, where higher sales contribute to greater profitability for a business.*

# %%
#Negative Correlation:
sns.lmplot(x='Profit',y='Discount',data=df)
plt.title("Negative Correlation - Profit and Discount")
# Out:
# Text(0.5, 1.0, 'Negative Correlation - Profit and Discount')

# %% [markdown]
# *A negative correlation between discount and profit suggests that as discounts increase, profits tend to decrease. Focusing more on discounting may attract customers but could potentially erode profitability.*

# %%
#Zero Correlation:
sns.lmplot(x='Quantity',y='Discount',data=df)
plt.title("Zero Correlation - Quantity and Discount")
# Out:
# Text(0.5, 1.0, 'Zero Correlation - Quantity and Discount')

# %% [markdown]
# *A zero correlation between quantity and discount indicates that changes in the quantity of a product purchased are not associated with any consistent changes in the discount applied to that product. In other words, the two variables do not show a linear relationship or influence each other.*

# %% [markdown]
# # Outliers

# %%
#Find the outliers
sns.set(rc={'figure.figsize':(10,5)})
sns.boxplot(x='Sales',data=df)
plt.title("Boxplot-Sales Data")
# Out:
# Text(0.5, 1.0, 'Boxplot-Sales Data')

# %%
#Sales data distribution/ statistics:
df['Sales'].describe()
# Out:
# count     9977.000000
# mean       229.558885
# std        623.697719
# min          0.000000
# 25%         17.000000
# 50%         54.000000
# 75%        209.000000
# max      22638.000000
# Name: Sales, dtype: float64

# %% [markdown]
# # IQR Method

# %%
q1=df.Sales.quantile(.25)
q3=df.Sales.quantile(.55)
Iqr=q3-q1
lower_limit=q1-1.5*Iqr
upper_limit=q1+1.5*Iqr

# %% [markdown]
# # Finding Outliers

# %%
df[df.Sales<upper_limit]
# Out:
#            Ship Mode    Segment             City       State Region  \
# 2       Second Class  Corporate      Los Angeles  California   West
# 4     Standard Class   Consumer  Fort Lauderdale     Florida  South
# 5     Standard Class   Consumer      Los Angeles  California   West
# 6     Standard Class   Consumer      Los Angeles  California   West
# 8     Standard Class   Consumer      Los Angeles  California   West
# ...              ...        ...              ...         ...    ...
# 9986  Standard Class   Consumer      Los Angeles  California   West
# 9987  Standard Class  Corporate           Athens     Georgia  South
# 9989    Second Class   Consumer            Miami     Florida  South
# 9990  Standard Class   Consumer       Costa Mesa  California   West
# 9992  Standard Class   Consumer       Costa Mesa  California   West
#
#              Category Sub-Category  Sales  Quantity  Discount  Profit
# 2     Office Supplies       Labels     14         2       0.0       6
# ...

# %%
df[df.Sales>lower_limit]
# Out:
#            Ship Mode    Segment             City       State Region  \
# 0       Second Class   Consumer        Henderson    Kentucky  South
# 1       Second Class   Consumer        Henderson    Kentucky  South
# 2       Second Class  Corporate      Los Angeles  California   West
# 3     Standard Class   Consumer  Fort Lauderdale     Florida  South
# 4     Standard Class   Consumer  Fort Lauderdale     Florida  South
# ...              ...        ...              ...         ...    ...
# 9989    Second Class   Consumer            Miami     Florida  South
# 9990  Standard Class   Consumer       Costa Mesa  California   West
# 9991  Standard Class   Consumer       Costa Mesa  California   West
# 9992  Standard Class   Consumer       Costa Mesa  California   West
# 9993    Second Class   Consumer      Westminster  California   West
#
#              Category Sub-Category  Sales  Quantity  Discount  Profit
# 0           Furniture    Bookcases    261         2      0.00      41
# ...

# %% [markdown]
# # Remove outliers

# %%
new_df=df[(df.Sales>lower_limit)&(df.Sales<upper_limit)]
print("old data:",len(df))
print("new data:",len(new_df))
print("No.of.outliers:",len(df)-len(new_df))
# Out:
# old data: 9977
# new data: 6089
# No.of.outliers: 3888

# %%
new_df.shape
# Out:
# (6089, 11)

# %%
plt.subplot(1,2,1)
sns.boxplot(x='Sales',data=df)
plt.xlabel("Old Sales")

plt.suptitle("Old Sales data and New Sales data")
plt.subplot(1,2,2)
sns.boxplot(x='Sales',data=new_df)
plt.xlabel("New Sales")
# Out:
# Text(0.5, 0, 'New Sales')

# %%
new_df
# Out:
#            Ship Mode    Segment             City       State Region  \
# 2       Second Class  Corporate      Los Angeles  California   West
# 4     Standard Class   Consumer  Fort Lauderdale     Florida  South
# 5     Standard Class   Consumer      Los Angeles  California   West
# 6     Standard Class   Consumer      Los Angeles  California   West
# 8     Standard Class   Consumer      Los Angeles  California   West
# ...              ...        ...              ...         ...    ...
# 9986  Standard Class   Consumer      Los Angeles  California   West
# 9987  Standard Class  Corporate           Athens     Georgia  South
# 9989    Second Class   Consumer            Miami     Florida  South
# 9990  Standard Class   Consumer       Costa Mesa  California   West
# 9992  Standard Class   Consumer       Costa Mesa  California   West
#
#              Category Sub-Category  Sales  Quantity  Discount  Profit
# 2     Office Supplies       Labels     14         2       0.0       6
# ...

# %% [markdown]
# *After removing all outliers from the dataset, the analysis becomes more robust and representative of the central trend, enhancing the reliability of statistical conclusions.*

# %% [markdown]
# # Univariate Analysis

# %%
# Segment:
sns.set(rc={'figure.figsize':(5,5)})
seg=sns.countplot(x='Segment',data=new_df)
plt.title('Count of Segment')

for i in seg.containers:
    seg.bar_label(i)

# %%
#Category:
sns.set(rc={'figure.figsize':(5,5)})
category=sns.countplot(x='Category',data=new_df)
plt.title('Count of Category')


for i in category.containers:
    category.bar_label(i)

# %%
#Sub-Category:
sns.set(rc={'figure.figsize':(20,7)})
sub_category=sns.countplot(x='Sub-Category',data=new_df)
plt.title('Count of Sub-category')


for i in sub_category.containers:
    sub_category.bar_label(i)

# %%
#Region:
sns.set(rc={'figure.figsize':(10,5)})
x=new_df['Region'].value_counts()
plt.pie(x.values,labels=x.index,autopct='%1.2f%%',explode=[0.2,0,0,0])
plt.legend()
plt.show()

# %%
#State:
sns.set(rc={'figure.figsize':(15,7)})
state=sns.countplot(x='State',data=new_df)
plt.xticks(rotation=90)
plt.title('Count of State')


for i in state.containers:
    state.bar_label(i)

# %% [markdown]
# # Bivariate Analysis

# %%
#1.Which region has a higher number of sales
sns.set(rc={'figure.figsize':(10,5)})
state=new_df.groupby('Region').sum().plot(kind='pie',y='Sales',autopct='%2.1f%%',title='Which region has a higher number of sales')
state
# Out:
# C:\Users\91934\AppData\Local\Temp\ipykernel_17164\858452742.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   state=new_df.groupby('Region').sum().plot(kind='pie',y='Sales',autopct='%2.1f%%',title='Which region has a higher number of sales')
# <Axes: title={'center': 'Which region has a higher number of sales'}, ylabel='Sales'>

# %%
#2.Which state has the highest number of sales on top state:
sns.set(rc={'figure.figsize':(12,5)})
state=new_df.groupby('State',as_index=False)['Sales'].sum().sort_values(by='Sales',ascending=False).head(10)
sns.barplot(x='State',y='Sales',data=state)
plt.title('Which state has the highest number of sales on top 10 State')
# Out:
# Text(0.5, 1.0, 'Which state has the highest number of sales on top 10 State')

# %%
#3.Which City has the highest number of sales on top state:
sns.set(rc={'figure.figsize':(15,5)})
city=new_df.groupby('City',as_index=False)['Sales'].sum().sort_values(by='Sales',ascending=False).head(10)
sns.barplot(x='City',y='Sales',data=city)
plt.title('Which city has the highest number of sales on top 10 city')
# Out:
# Text(0.5, 1.0, 'Which city has the highest number of sales on top 10 city')

# %%
#4.Which Category has the highest number of sales on top state:
sns.set(rc={'figure.figsize':(5,5)})
Category=new_df.groupby('Category',as_index=False)['Sales'].sum().sort_values(by='Sales',ascending=False)
sns.barplot(x='Category',y='Sales',data=Category)
plt.title('Which Category has the highest number of sales')
# Out:
# Text(0.5, 1.0, 'Which Category has the highest number of sales')

# %%
#5.Which Sub-Category has the highest number of sales on top 10 products:
sns.set(rc={'figure.figsize':(15,5)})
SCategory=new_df.groupby('Sub-Category',as_index=False)['Sales'].sum().sort_values(by='Sales',ascending=False).head(10)
sns.barplot(x='Sub-Category',y='Sales',data=SCategory)
plt.title('Which Sub-Category has the highest number of sales on top 10 products')
# Out:
# Text(0.5, 1.0, 'Which Sub-Category has the highest number of sales on top 10 products')

# %%
#6.Discount and category:
sort=new_df.sort_values('Discount',ascending=False)
sns.barplot(x='Category',y='Discount',hue='Region',data=sort)
plt.title('Discount and Category')
# Out:
# Text(0.5, 1.0, 'Discount and Category')

# %% [markdown]
# # Conclusion

# %% [markdown]
# *In summary of the Superstore analysis, the focus is on sales in the western region, specifically in California, with a spotlight on the city of New York. The analysis reveals that the highest-selling product category is office supplies, particularly paper. This underscores the significance of targeting and optimizing sales strategies for office supplies, especially paper, in the specified region and locations. Adjusting marketing and inventory efforts to capitalize on the demand for these specific products could potentially lead to increased profitability and market share.*
